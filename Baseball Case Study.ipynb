# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Loading and Exploring

# %%
# loading dataset
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Checking the shape of the dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns in this dataset.

# %%
# Checking for data types
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# All our data is in numerical form.

# %%
# Checking for Missing Values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no Missing Values.

# %%
# Seprating Target Varible and Input Features
features = ['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'E']
X = df[features]
y = df['W']

# %% [markdown]
# ### Data Visualization

# %%
# Setting a custom color palette
custom_palette = sns.color_palette("husl", len(features))
# Plotting distributions
plt.figure(figsize=(20, 15))
for i, feature in enumerate(features):
    plt.subplot(4, 4, i + 1)
    sns.histplot(df[feature], kde=True,color=custom_palette[i])
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Runs (R): Most teams score between 650 and 720 runs, with a few scoring significantly higher or lower.
# At Bats (AB): The distribution is relatively uniform.
# Hits (H): Most teams have between 1325 and 1400 hits.
# Doubles (2B): Teams typically hit between 260 and 290 doubles.
# Triples (3B): The distribution is right-skewed, with most teams hitting fewer than 40 triples.
# Home Runs (HR): Teams generally hit between 140 and 180 home runs, with a few hitting over 200.
# Walks (BB): Most teams draw between 420 and 500 walks.
# Strikeouts (SO): Teams generally strike out between 1150 and 1350 times.
# Stolen Bases (SB): Distribution is right-skewed, with most teams stealing fewer than 100 bases.
# Runs Allowed (RA): Most teams allow between 600 and 750 runs.
# Earned Runs (ER): Similar to RA, most teams allow between 600 and 700 earned runs.
# Earned Run Average (ERA): Most teams have an ERA between 3.5 and 4.5.
# Errors (E): Teams typically commit between 80 and 100 errors.

# %%
# Creating a histogram plot for Wins (W)
plt.figure(figsize=(10, 6))
sns.histplot(df['W'], kde=True,color='skyblue')
plt.title('Distribution of Wins (W)')
plt.xlabel('Number of Wins')
plt.ylabel('Frequency')
plt.show()

# %%
# Creating box plots for all input features
plt.figure(figsize=(16, 10))
for i, feature in enumerate(features):
    plt.subplot(4, 4, i + 1)
    sns.boxplot(x=df[feature],palette='YlGnBu')
    plt.title(f'Boxplot of {feature}')
    plt.xlabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# From the output above we can see the IQR i.e Inter Quartile Range where majority of the data lies and we can also see the presence of outliers in features like R,ERA,SHO,E.

# %%
# Summary Statistics
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# Correlation heatmap
plt.figure(figsize=(16, 10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Feature Scaling

# %%
# Scaling the Dataset
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Converting the scaled features back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# Displaying the first few rows of the scaled dataset
print(X_scaled_df.head())
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1  0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2 -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3 -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4  0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.697630  0.913883 -0.666234 -0.505110 -0.506955 -0.539806 -0.814629
# 1  0.154878 -0.601826  0.165971  0.248930  0.254598 -0.539806  0.172800
# 2 -0.893982  0.111449 -0.680339 -0.751623 -0.641347  2.772641 -0.320914
# 3 -0.168602 -0.690985  0.180076  0.103922  0.053010  1.300442 -0.567771
# 4  0.105866 -0.022290  1.618803  1.597501  1.531318  1.300442  0.172800
#
#          SV         E
# 0  1.671607 -0.461470
# 1  0.249879 -0.607197
# 2 -0.654856 -1.117242
# ...

# %% [markdown]
# ### Splitting the Data

# %%
# Data Splitting
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (24, 16)
# (6, 16)
# (24,)
# (6,)

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Linear Regression
lr_model = LinearRegression()
lr_model.fit(X_train, Y_train)

# Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, Y_train)

# Gradient Boosting Regressor
gb_model = GradientBoostingRegressor(random_state=42)
gb_model.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_model(model, X_test, Y_test):
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(Y_test, y_pred)
    mse = mean_squared_error(Y_test, y_pred)
    r2 = r2_score(Y_test, y_pred)
    return mae, mse, r2

# Evaluating Linear Regression
lr_metrics = evaluate_model(lr_model, X_test, Y_test)
# Evaluating Random Forest Regressor
rf_metrics = evaluate_model(rf_model, X_test, Y_test)
# Evaluating Gradient Boosting Regressor
gb_metrics = evaluate_model(gb_model, X_test, Y_test)

print("Linear Regression Metrics:", lr_metrics)
print("Random Forest Regressor Metrics:", rf_metrics)
print("Gradient Boosting Regressor Metrics:", gb_metrics)
# Out:
# Linear Regression Metrics: (3.892999136999857, 27.943032506667763, 0.7876400316149379)
# Random Forest Regressor Metrics: (5.75333333333333, 51.6134333333333, 0.6077509816339458)
# Gradient Boosting Regressor Metrics: (5.980689066453098, 47.69939359453528, 0.6374966921251277)

# %% [markdown]
# From the all the models above Linear Reggression model is peroforming best.
